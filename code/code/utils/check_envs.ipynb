# %%
import tensorflow as tf, os

print("*" * 50)
print("Test Tensorflow GPUs")
print("*" * 50)

list_gpus = tf.config.experimental.list_physical_devices()
print("Number of GPUs: ");
for gpu in list_gpus: print(f"+ {gpu}")
print()

print("*" * 50)
print("Test Pytorch GPUs")
print("*" * 50)
print()
# Out:
# **************************************************
# Test Tensorflow GPUs
# **************************************************
# Number of GPUs:
# + PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')
# **************************************************
# Test Pytorch GPUs
# **************************************************
